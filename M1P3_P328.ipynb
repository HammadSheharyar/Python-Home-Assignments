# %% [markdown]
# <a href="https://colab.research.google.com/github/HammadSheharyar/Python-Home-Assignments/blob/main/M1P3_P328.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# printing a name
print("Hammad")
# getting input from the user
input()

# %%
# Athematic operations
# operators ====> +, - , *, / , //, **
print(2 + 2)
print(2 - 2)
print(2*2)
print(int(2/2))
print(8 / 4)
# floor division //
print(8 // 4)
# 2^2, 2^3
print(3 ** 4)
# Out:
# 4
# 0
# 4
# 1
# 2.0
# 2
# 81

# %%
# typing casting
print(int(2.2))
print(float(2))
# 2 ====> ' 2 '
str(2)
type(str(2))
num_1 = '2'
num_2 = float(num_1)

print(type(num_2))
# Out:
# 2
# 2.0
# <class 'float'>

# %%
print("hello " + "world")
# Out:
# hello world

# %%
_name = "hammad"

# %%
str1 = str()
STR1 = ""
str2 = "ali"
# len() function
print(len(str1))
print(len(str2))
print(len("muhammad 434 ali"))
list1 = [1,23,4,34,4556,6767,3434,454,56]
print(len(list1))
# Out:
# 0
# 3
# 16
# 9

# %%
len("")
# Out:
# 0

# %%
# number = "12"
# number_of_digits =
# print()

# %%
# modulo operator (%)
print(8 % 2)
print(8 % 3)
# Out:
# 0
# 2

# %%
str_1 = "Hi "
print(str_1*3)
str_2 = "ha"
print(str_2*5)
# Out:
# Hi Hi Hi
# hahahahaha

# %%
a = str(3.14) + '159'
print(a)
# Out:
# 3.14159

# %%
print(3.14 + 159)
# Out:
# 162.14

# %%
print(2 *'this')
# Out:
# thisthis

# %%
my_age = 10
is_a_coder = True

# %%
count = 10
# increase count by 1
count = count + 1
print(count)
# decrease count by 1
count = count - 1
print(count)
# myltiply by 2
count = count * 2
print(count)
# Out:
# 11
# 10

# %%
count = 10
# increase count by 1
# count = count + 1
count += 1
print(count)
# count = count - 1
count -= 1
print(count)
count *=2
print(count)
# Out:
# 11
# 10
# 20

# %%
# round() ---- 99
# 2.3434533 ------ 2.34
print(round(2.34333433444))
# Out:
# 2.0

# %%
round(9990, -3)
# Out:
# 10000

# %%
round(90, -1)
# Out:
# 90

# %%
round(990, -2)
# Out:
# 1000

# %%
round(12345, -3)
# Out:
# 12000

# %%
round(45, -1)
# Out:
# 40

# %%
round(345, -2)
# Out:
# 300

# %%
round(2345, -3)
# Out:
# 2000

# %%
# Area of the triangle

# %%
# comparison operators
# <, >, >=,<= , ==, !=
print(100 < 20 )
# Out:
# False

# %%
# > or =
print(1000 >= 100)
# Out:
# True

# %%
print(10 <= 100)
# Out:
# True

# %%
print(100 <= 100)
# Out:
# True

# %%
a = 100
b = 1000
print(a == b)
# Out:
# False

# %%
print(200 == 200)
# Out:
# True

# %%
print(100 != 1000)
# Out:
# True

# %%
# Logical Operators
# and, or , not
#
print(1 > 2 and  2 > 3)
print(2 > 1 and 1 > 2)

print(2> 1 and 3>2)
print(1 and 1)
print(True and True)
print(1 and 0)
# 1,2,3
print(1 and 2)
print(0 and 2)
# Out:
# False
# False
# True
# 1
# True
# 0
# 2
# 0

# %%
# Or operator
print(1 > 2 or 0  > 1)
# Out:
# False

# %%
# not opeartor
print(not(0))
print(not(1))
# Out:
# True
# False

# %%
print(not(1 > 2 and  2 > 3))
# Out:
# True

# %%
print(not(1  > 2))
print(not(0<1))
# Out:
# True
# False

# %%
print(not 1)
# Out:
# False

# %%
# Condtional Statements
condition = False
if condition:
  # do something
  print("Condition is True")
  print("Condition is True")

  print("Condition is True")

  print("Condition is True")
  print("Condition is True")



print("i am outside the body of if block")
# Out:
# Condition is True
# Condition is True
# Condition is True
# Condition is True
# Condition is True
# i am outside the body of if block

# %%
if False:
  print(5 < 7)

# %%
if True:
  print(5<7)
# Out:
# True

# %%
condition = False
if condition:
  print("Condiotin is True")

condition2 = False
if condition2:

  print("The conditon is true")

print("i am independent on the if blocks, i will always run weather conditions are trur or false")
# Out:
# i am independent on the if blocks, i will always run weather conditions are trur or false

# %%
a = 10
if a < 20:
  print("Condition is True")
  b = 10
  print(b)
# Out:
# Condition is True
# 10

# %%
# multiple conditions
b = 5
c =15
if b > 10 and c > 20:
  print("Both conditions are true")

# %%
b > 10 and c > 20
# Out:
# False

# %%
# if-else block
b = 4
if b == 5:
  print("b is 5")

else:
  print("b is not 5")

# %%
# even and odd number
number = int(input("Enter the number: "))
if

# %%
# take password from user
# password = "python"
# welcome message
# access denied

# %%
# 3 numbers
# largest number of three numbers

# %%
a=int(input(" enter the first number "))
b= int( input("enter the second number"))
c=int(input("enter the  third number"))
if a>b>c:
  print(" a is greatest")
elif b>a>c:
  print(" b is greatest")
else:
  print()
# Out:
#  enter the first number 44
# enter the second number0
# enter the  third number8

# %%
# nested if-else condiotion
if condition:

  if condition:

  else:


else:

# %%
# Out:
# Enter the username: admin
# Enter the password: 1222
# incorrect password

# %%
# Login System
username = input("Enter the username: ")
password = input("Enter the password: ")
if username == "admin":
  if password == "1234":
    print("Login Successfully!")

  else:
    print("incorrect password")


else:

  print("unknown username")
# Out:
# Enter the username: adminn
# Enter the password: 112121
# unknown username

# %%
username = input("Enter the username: ")
password = input("Enter the password: ")
if username == "admin" and password == "1234":
  print("login")


else:
  print("unknown username")
# Out:
# Enter the username: qew
# Enter the password: 2322
# unknown username

# %%
marks = int(input("enter marks"))
if marks >= 0 and marks <= 100:
  if marks >= 90:
    print("A+")
  elif marks >= 80:
    print("A")
  elif marks >= 70:
    print("B")
  elif marks >= 60:
    print("C")
  elif marks >= 50:
    print("D")
  else:
    print("F")

else:
  print("invalid marks")
# Out:
# enter marks-90
# invalid marks

# %%
# check  if number is posiive, so find that if it is even or odd,
# else negative

# %%
number = int(input("Enter a number: "))
if number >= 0:
  if number % 2 == 0:
    print("positive and even number.")
  else:
    print("postive and odd number.")

else:
  if number % 2 == 0:
    print("negative and even number.")
  else:
    print("negative and odd number.")
# Out:
# Enter a number: -10
# negative and even number.

# %%
account_status = True
balance = 5000
withdraw_amount = 2000
daily_limit = 3000
if account_status:
  if balance >= withdraw_amount:
    if withdraw_amount <= daily_limit:
      print("transaction successfull")
    else:
      print("amount exceeds daily limit")

  else:
    print("insufficent balance")

else:
  print("inactive account")
# Out:
# transaction successfull

# %%
"""
Task
Given an integer, n , perform the following conditional actions:

If n  is odd, print Weird
If n is even and in the inclusive range of 2 to 5, print Not Weird
If n is even and in the inclusive range of 6 to 20, print Weird
If n is even and greater than 20, print Not Weird
Input Format

A single line containing a positive integer, .
Output Format

Print Weird if the number is weird. Otherwise, print Not Weird.

Sample Input:

3
Sample Output:

Weird


"""

# %%
"""

Task no 2:

An extra day is added to the calendar almost every four years as February 29, and the day is called a leap day. It corrects the calendar for the fact that our planet takes approximately 365.25 days to orbit the sun. A leap year contains a leap day.

In the Gregorian calendar, three conditions are used to identify leap years:

The year can be evenly divided by 4, is a leap year, unless:
The year can be evenly divided by 100, it is NOT a leap year, unless:
The year is also evenly divisible by 400. Then it is a leap year.
This means that in the Gregorian calendar, the years 2000 and 2400 are leap years, while 1800, 1900, 2100, 2200, 2300 and 2500 are NOT leap years. Source

Task

Given a year, determine whether it is a leap year. If it is a leap year, return the Boolean True, otherwise return False.

Note that the code stub provided reads from STDIN and passes arguments to the is_leap function. It is only necessary to complete the is_leap function.

Input Format

Read , the year to test.

Constraints


Output Format

The function must return a Boolean value (True/False). Output is handled by the provided code stub.

Sample Input 0

1990
Sample Output 0

False

"""

# %%
"""
The year must be evenly divisible by 4;
If the year can also be evenly divided by 100, it is not a leap year;
unless...
The year is also evenly divisible by 400. Then it is a leap year.
"""

# %%
"""
a , b , c


"""

# %%
x= False
if x:
  print("Yes")
else:
  print("No")
# Out:
# No

# %%
x = 10;
if x != 10:
  print("No");
else: print("Yes")
# Out:
# Yes

# %%
x = 1;
if x > 2:
  if x < 10:
    print("Inside")
else:
  print("outside")
# Out:
# outside

# %%
x = 4
y = 8;
if y // x == 2:
  print("Okay")

# %%
"""
"Identify the Type of Triangle using Python"
📝 Problem Statement:
Write a Python program that accepts the lengths of three sides of a triangle and determines:
Whether the given sides can form a valid triangle or not.


If valid, determine whether the triangle is:


      Equilateral (all sides equal)


      Isosceles (two sides equal)


      Scalene (all sides different)


📘 Conditions to Remember:
A triangle is valid only if the sum of any two sides is greater than the third side.
 That is:
(a + b) > c
(a + c) > b
(b + c) > a

💡 Hints:
Take inputs for the three sides.


First, check if the triangle is valid.


If valid, use conditional statements to identify its type.


Display appropriate messages for each case.


📤 Expected Output Example:
Enter side a: 5
Enter side b: 5
Enter side c: 8

These sides can form a triangle.
Type: Isosceles Triangle


"""

# %%
a =
b =
c =
if  a+ b > c and a + c > b and b + c > a:

  if a == b and b == c:
    print("equilateral")
  elif a==b or a == c or b == c:
    print("isolece")

  else:
    print("scalene")

else:
  print("not valid ")

# %%
print("===============================================")
print("🎉  MATH FUN CALCULATOR 🎨")
print("===============================================")
print("1. Basic Arithmetic (Add, Subtract, Multiply, Divide)")
print("2. Square and Cube of a Number")
print("3. Check if a Number is Even or Odd")
print("4. Find the Greater of Two Numbers")
print("5. Find the Area of Basic Shapes")
print("6. Exit")
print("===============================================")

# %%
# Conditional Expression =====>>>>> short/simplified verision of if-else condition
x = 10
y = 20
if x > y :
  print(x)

else:
  print(y)
# Out:
# 20

# %%
greater = x if x>y else y
print(greater)
# Out:
# 20

# %%
# value__if_true if condition else value__if_false
x = int(input())
num = "Even" if x % 2 == 0 else "Odd"
print(num)
# Out:
# 20
# Even

# %%
"""
Write a Python program that acts like a Math Quiz Game.
The program should display a menu of different math challenges,
ask the user a question, get their answer, and then tell them if their answer is correct or not.

The menu should be:
1. Addition Challenge
2. Subtraction Challenge
3. Multiplication Challenge
4. Division Challenge
5. Number Comparison
6. Exit

Your program should:
Display the menu once.


Ask the user to pick a challenge (1–6).
Take the required inputs (numbers).
Ask the user for their answer to a math problem.
Check if it’s correct or wrong, then display a message.
"""
print("===============================================")
print("🎉  Math Quiz Game 🎨")
print("===============================================")
print("1. Addition Challenge")
print("2. Subtraction Challenge")
print("3. Multiplication Challenge")
print("4. Division Challenge")
print("5. Number Comparison")
print("6. Exit")
print("===============================================")
# Out:
# ...
# 🎉  Math Quiz Game 🎨
# ...
# 1. Addition Challenge
# 2. Subtraction Challenge
# 3. Multiplication Challenge
# 4. Division Challenge
# 5. FNumber Comparison
# 6. Exit
# ...

# %%
Task1:

"""
Create a Python program that acts as a Math Puzzle Builder.
The program should:
Present 3–4 different math puzzles (addition, subtraction, multiplication, division, or comparing numbers).


Ask the user to answer each puzzle.


Keep track of correct answers and calculate a score at the end.


Display a final message based on the score.
score = 0
score += 1


"""
# Your output should be like this
"""
🧩 Example Output
Puzzle 1: Addition
Enter first number: 5
Enter second number: 3
What is 5.0 + 3.0? 8
✅ Correct!

Puzzle 2: Subtraction
Enter first number: 9
Enter second number: 4
What is 9.0 - 4.0? 6
❌ Wrong!

Puzzle 3: Multiplication
Enter first number: 2
Enter second number: 6
What is 2.0 × 6.0? 12
✅ Correct!

Puzzle 4: Compare Numbers
Enter first number: 7
Enter second number: 7
Which number is greater? (a/b/equal): equal
✅ Correct!

🏆 Your Score: 3 / 4
👍 Good Job! Keep Practicing!

"""

# %%
print("===============================================")
print("🧩MATH PUZZLE BUILDER 🧮")
print("Solve puzzles and see your score!")
print("===============================================\n")
score=0
print("puzzel 1 addition")
num1=int(input("enter number"))
num2=int(input("enter number"))
user_answer=int(input(f"what is {num1}+{num2} "))
if user_answer == num1+num2:
  print("correct answer")
  score+=1
else:
  print("wrong answer")
print("puzzel 2 subtraction")
num3=int(input("enter number"))
num4=int(input("enter number"))
user_answer=int((f"what is {num3}-{num4}"))
if user_answer==num3-num4:
  print("correct answer")
  score+=1
else:
  print("wrong answer")
print("puzzel 3 multiplycation")
num5=int(input("enter number"))
num6=int(input("enter number"))
user_answer=int(input(f"what is {num5}*{num6}"))
if user_answer==num5*num6:
  print("correct answer")
  score+=1
else:
  print("wrong answer")
print(" puzzel 4 comaring numbers")
num7=int(input("enter number"))
num8=int(input("enter number"))
user_answer=int((f"which one is greater {num7}<{num8} or {num7}>{num8}"))
if user_answer==num7<num8:
   print("correct answer")
   score+=1
else:
  print("wrong answer")




Task1:
"""
Create a Python program that acts as a Math Puzzle Builder.
The program should:
Present 3–4 different math puzzles (addition, subtraction, multiplication, division, or comparing numbers).

Ask the user to answer each puzzle.

Keep track of correct answers and calculate a score at the end.

Display a final message based on the score.
score = 0
score += 1

"""
# Your output should be like this
"""
🧩 Example Output
Puzzle 1: Addition
Enter first number: 5
Enter second number: 3
What is 5.0 + 3.0? 8
✅ Correct!
Puzzle 2: Subtraction
Enter first number: 9
Enter second number: 4
What is 9.0 - 4.0? 6
❌ Wrong!
Puzzle 3: Multiplication
Enter first number: 2
Enter second number: 6
What is 2.0 × 6.0? 12
✅ Correct!
Puzzle 4: Compare Numbers
Enter first number: 7
Enter second number: 7
Which number is greater? (a/b/equal): equal
✅ Correct!
🏆 Your Score: 3 / 4
👍 Good Job! Keep Practicing!
"""
print("===============================================")
print("🧩MATH PUZZLE BUILDER 🧮")
print("Solve puzzles and see your score!")
print("===============================================\n")
score=0
print("puzzel 1 addition")
num1=int(input("enter number"))
num2=int(input("enter number"))
user_answer=int(input(f"what is {num1}+{num2} "))
if user_answer == num1+num2:
  print("correct answer")
  score+=1
else:
  print("wrong answer")
print("puzzel 2 subtraction")
num3=int(input("enter number"))
num4=int(input("enter number"))
user_answer=int((f"what is {num3}-{num4}"))
if user_answer==num3-num4:
  print("correct answer")
  score+=1
else:
  print("wrong answer")
print("puzzel 3 multiplycation")
num5=int(input("enter number"))
num6=int(input("enter number"))
user_answer=int(input(f"what is {num5}*{num6}"))
if user_answer==num5*num6:
  print("correct answer")
  score+=1
else:
  print("wrong answer")
print(" puzzel 4 comaring numbers")
num7=int(input("enter number"))
num8=int(input("enter number"))
user_answer=int((f"which one is greater {num7}<{num8} or {num7}>{num8}"))
if user_answer==num7<num8:
   print("correct answer")
   score+=1
else:
  print("wrong answer")




Task1:
"""
Create a Python program that acts as a Math Puzzle Builder.
The program should:
Present 3–4 different math puzzles (addition, subtraction, multiplication, division, or comparing numbers).

Ask the user to answer each puzzle.

Keep track of correct answers and calculate a score at the end.

Display a final message based on the score.
score = 0
score += 1

"""
# Your output should be like this
"""
🧩 Example Output
Puzzle 1: Addition
Enter first number: 5
Enter second number: 3
What is 5.0 + 3.0? 8
✅ Correct!
Puzzle 2: Subtraction
Enter first number: 9
Enter second number: 4
What is 9.0 - 4.0? 6
❌ Wrong!
Puzzle 3: Multiplication
Enter first number: 2
Enter second number: 6
What is 2.0 × 6.0? 12
✅ Correct!
Puzzle 4: Compare Numbers
Enter first number: 7
Enter second number: 7
Which number is greater? (a/b/equal): equal
✅ Correct!
🏆 Your Score: 3 / 4
👍 Good Job! Keep Practicing!
"""
print("===============================================")
print("🧩MATH PUZZLE BUILDER 🧮")
print("Solve puzzles and see your score!")
print("===============================================\n")
score=0
print("puzzel 1 addition")
num1=int(input("enter number"))
num2=int(input("enter number"))
user_answer=int(input(f"what is {num1}+{num2} "))
if user_answer == num1+num2:
  print("correct answer")
  score+=1
else:
  print("wrong answer")
print("puzzel 2 subtraction")
num3=int(input("enter number"))
num4=int(input("enter number"))
user_answer=int((f"what is {num3}-{num4}"))
if user_answer==num3-num4:
  print("correct answer")
  score+=1
else:
  print("wrong answer")
print("puzzel 3 multiplycation")
num5=int(input("enter number"))
num6=int(input("enter number"))
user_answer=int(input(f"what is {num5}*{num6}"))
if user_answer==num5*num6:
  print("correct answer")
  score+=1
else:
  print("wrong answer")
print(" puzzel 4 comaring numbers")
num7=int(input("enter number"))
num8=int(input("enter number"))
user_answer=int((f"which one is greater {num7}<{num8} or {num7}>{num8}"))
if user_answer==num7<num8:
   print("correct answer")
   score+=1
else:
  print("wrong answer")

# %%
# Loops in Python
# While loop
# For Loop
while condition:
  # do something
  # code here
  # code here
  pass

# %%
count = 1
while count <= 5:
  print(count)
  count +=1

print("completed")
# Out:
# 1
# 2
# 3
# 4
# 5
# completed

# %%
num = 1
while num <= 5:
  print("hello")
  num = num + 1
# Out:
# hello
# hello
# hello
# hello
# hello

# %%
num = 10
while num >= 5:
  print(num)
  num -=1
# Out:
# 10
# 9
# 8
# 7
# 6
# 5

# %%
command = ""
while command != "stop":
  command = input("Type a command! ")

print("Program ended")
# Out:
# Type a command! 123
# Type a command! stop
# Program ended

# %%
number=2
while number <= 100:
  if number % 2==0:
    print(number)
    number+=1

print("done")

# %%
number=2
while number <= 100:
  print(number)
  if number % 2 == 0:
    print(number)
    number+=1

# %%
"""
Suppose we want to add the numbers from 1 to 10.


"""

num = 1
sum = 0
while num <= 10:
  sum = sum + num
  num = num + 1

print(sum)
# Out:
# 55

# %%
7 % 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-2528938823.py in <cell line: 0>()
# ----> 1 7 % 0
#
# ZeroDivisionError: integer modulo by zero

# %%
8 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-844477100.py in <cell line: 0>()
# ----> 1 8 / 0
#
# ZeroDivisionError: division by zero

# %%
3 ** 4
# Out:
# 81
