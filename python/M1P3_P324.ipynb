# %% [markdown]
# <a href="https://colab.research.google.com/github/HammadSheharyar/Python-Home-Assignments/blob/main/python/M1P3_P324.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1:

# %%
print(2,3,3,2)
print("hi" , "python", "programming", 2, sep = ",")
# Out:
# 2 3 3 2
# hi,python,programming,2

# %%
# \n new line
print("My name is Ali.\nMy age is 10. \nPython Programming Language.")
print()
# Out:
# My name is Ali.
# My age is 10.
# Python Programming Language.

# %% [markdown]
# Task 1:

# %%
input("Enter the number: ")
# Out:
# Enter the number: 67
# '67'

# %%
input("Enter your name: ")
input("What is age? ")
input("What is your favourite animal? ")
# Out:
# Enter your name: ALI
# What is age? 10
# What is your favourite animal? CAT
# 'CAT'

# %% [markdown]
# Task 3:

# %%
my_age = input("What is your age? ")
# Out:
# What is your age? 10

# %%
print("My age is", my_age)
# Out:
# My age is 10

# %%
print("Python\nProgramming\nLanguage")
# Out:
# Python
# Programming
# Language

# %%
# Arthmatic operators ------> +, -, * , /, **
# Addition , +
print(1+1)
print(3 - 2)
print(10 * 20)
# division
print(4 / 2)
print(8 / 2)
# floor division
print(4 // 2)
print(8 // 2)
# power operation / exponent
print(2 ** 6)
# Out:
# 2
# 1
# 200
# 2.0
# 4.0
# 2
# 4
# 64

# %%
print(" I said 'Hello!' to my friend. ")
# Out:
#  I said 'Hello!' to my friend.

# %%
type(3)
# Out:
# int

# %%
type(8.6)
# Out:
# float

# %%
print(type("hello"))
print(type('5555'))
# Out:
# <class 'str'>
# <class 'str'>

# %%
type(False)
# Out:
# bool

# %%
type(True)
# Out:
# bool

# %%
print(3 > 5)
print(8 < 9)
# Out:
# False
# True

# %%
# 2.4
int(2.4)
# Out:
# 2

# %%
# 2
float(2)
# Out:
# 2.0

# %%
# "2" ----string
int("2")
# Out:
# 2

# %%
float("2")
# Out:
# 2.0

# %%
input("Enter your number: ")
# Out:
# Enter your number: 20
# '20'

# %%
int(input("Enter the number: "))
# Out:
# Enter the number: 20
# 20

# %% [markdown]
# Task 1:

# %%
int(input("Enter a number"))
# Out:
# Enter a number10
# 10

# %%
float(input("Enter a number: "))
# Out:
# Enter a number: 2
# 2.0

# %% [markdown]
# Task 2:

# %%
int(2.3)
# Out:
# 2

# %% [markdown]
# Task 1:

# %%
input("What is your name? ")
input("What is favourite food? ")
input("video game? ")
# Out:
# What is your name? Hamad
# What is favourite food? Baryani
# vide game? gta
# 'gta'

# %%
2

# %%
# string concatanation
print("python" + " " + "programming" + " "  + "language")

print(4 + 5 + 6)

print("4" + "5" + "6")


print("4 + 5 + 6")
# Out:
# python programming language
# 15
# 456
# 4 + 5 + 6

# %%
# string multiplication
print("-"*50)
print("python "*3)

print("ha "*5)

print("-"* 50)
# Out:
# --------------------------------------------------
# python python python
# ha ha ha ha ha
# --------------------------------------------------

# %%
# length
len("python")
print(len("hello,     world 1232323"))
# Out:
# 24

# %%
# Variables
cool2 = 100

# %%
def = 34
# Out:
#   File "/tmp/ipython-input-2647066278.py", line 1
#     def = 34
#         ^
# SyntaxError: invalid syntax

# %%
my_name = "Codey"
print(my_name)
# Out:
# Codey

# %%
favourite_number = 7
print("my favourite number is", favourite_number)
# Out:
# my favourite number is 7

# %%
favourite_number + 44
# Out:
# 51

# %%
a = 10
b = 20
c = 30
name = "Mohid is python programmer"
print(c)
print(name)
a = 26
print(a)
b = 26
print(a , b)
# Out:
# 30
# Mohid is python programmer
# 26
# 26 26

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2167009006.py in <cell line: 0>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
b
# Out:
# 26

# %%
del b

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1685013873.py in <cell line: 0>()
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
a = 20
print(a)
print(id(a))
# Out:
# 20
# 11654984

# %%
is_going_to_school = True
print(is_going_to_school)
# Out:
# True

# %%
color = "Red"
print("The color is ", color)
# Out:
# The color is  Red

# %%
# num1
# num2
# sum, -, *, /, **
# Out:
# 16

# %%
# simple calculator program in python
print("Welcome to calculator")
number_1 = int(input("Enter the 1st number: "))
number_2 = int(input("Enter the 2nd number: "))
Addition = number_1 + number_2
subtraction = number_1 - number_2
multiplication = number_1 * number_2
division = number_1 / number_2
power = number_1 ** number_2
print("The result of addidtion is, ", Addition)
print("The result of subtraction is, " ,subtraction)
print("The result of multiplication is, ", multiplication)
print("The result of division is, ", division)
print("The result of power is, ", power)
# Out:
# Welcome to calculator
# Enter the 1st number: 5
# Enter the 2nd number: 5
# The result of addidtion is,  10
# The result of subtraction is,  0
# The result of multiplication is,  25
# The result of division is,  1.0
# The result of power is,  3125

# %%
print(number_1 + number_2)
print(number_1 - number_2)
print(number_1 * number_2)
print(number_1 / number_2)
print(number_1 ** number_2)
# Out:
# 15
# -1
# 56
# 0.875
# 5764801

# %%
# len() function in python
len("hi  123 ali")
# Out:
# 11

# %%
python = "programming"
print(python, "has ", len(python), "characters")
# Out:
# programming has  11 characters

# %%
name = "Ibrahim"
print(len(name))
name2 = "Abdulbasit   123"
print(len(name2))
# Out:
# 7
# 16

# %%
len("1")
# Out:
# 1

# %%
len("  ")
# Out:
# 2

# %%
string = ""
len(string)
# Out:
# 0

# %%
print(1 + 2*3)
# Out:
# 7

# %%
print((2 + 3)*3)
# Out:
# 15

# %%
paragraph =

"""

"""
#a


sdfsd

# %%
round(2.456, 1)
# Out:
# 2.5

# %%
round(2.456)
# Out:
# 2

# %%
round(0.1, 1)
# Out:
# 0.1

# %%
# base
# height
# area = 1/2 * (base * height)
# area_rounded = round(area, 1)
# round(area)

# %%
base = 7
height = 3.5
area = 1 / 2 * (base * height)
print("Area of triangle is ", area)
rounded_area = round(area, 1)
print("Area rounded to 1 place is ", rounded_area)
rounded_int = round(area)
print(rounded_int)
# Out:
# Area of triangle is  12.25
# Area rounded to 1 place is  12.2
# 12

# %%
# true division /
print(7/4)
print(4 / 2)
# Out:
# 1.75
# 2.0

# %%
# // floor division
print(4 // 2)
# Out:
# 2

# %%
print(7 // 4)
# Out:
# 1

# %%
# modulo operator %
print(8 % 2)
print(8 % 3)
# Out:
# 0
# 2

# %%
10 % 3
# Out:
# 1

# %%
print(7 % 4 )
# Out:
# 3

# %%
round(3.6)
# Out:
# 4

# %%
1 // 4
# Out:
# 0

# %%
round(9.999, 2)
# Out:
# 10.0

# %%
round(7.4)
# Out:
# 7

# %%
round(5/2)
# Out:
# 2

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-1455669704.py in <cell line: 0>()
# ----> 1 1 / 0
#
# ZeroDivisionError: division by zero

# %%
2 % 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-3431021326.py in <cell line: 0>()
# ----> 1 2 % 0
#
# ZeroDivisionError: integer modulo by zero

# %%
# comparison operators
# >, >=,  <, <= , ==, !=
2 > 3
# Out:
# False

# %%
3 > 2
# Out:
# True

# %%
print(100 > 200)
# Out:
# False

# %%
num1  = 200
num2 = 100
print(num1 > num2)
# Out:
# True

# %%
print(20 >= 200)
# Out:
# False

# %%
# >=

# %%
# <
print(2 < 3)
print(30 < 5)
# Out:
# True
# False

# %%
2 <= 2
# Out:
# True

# %%
# <=
print(2 <= 2)
# Out:
# True

# %%
# ==
print(1 == 1)
print(1 == 0)
# Out:
# True
# False

# %%
# !=
print( 2 != 3)
# Out:
# True

# %%
7 == 7
# Out:
# True

# %%
print("hello" == "hello")
# Out:
# True

# %%
print(25 == 20 - 5 )
# Out:
# False

# %%
print(7 != 7)

# %%
print("python" == "Python")
# Out:
# False

# %%
print(100 != 50*2)
# Out:
# False

# %%
#activity
"""
Use the input() function to ask the user for their first name and store it in a variable.
2. Ask for their age and store it.
3. Ask for their favorite subject in school and store it.
4. Use the len() function to get the length of their first name. Store this value.
5. Use int() to convert the user's age into an integer.
6. Perform the following calculation: (age ** 2) + len(first_name). Store the result in a
variable called calculation_result.

"""

# %%
print(a)
# Out:
# Use the input() function to ask the user for their first name and store it in a variable.
# 2. Ask for their age and store it.
# 3. Ask for their favorite subject in school and store it.
# 4. Use the len() function to get the length of their first name. Store this value.
# 5. Use int() to convert the user's age into an integer.
# 6. Perform the following calculation: (age ** 2) + len(first_name). Store the result in a
# variable called calculation_result.

# %%
#activity
"""
1. Use the input() function to ask the user for their first name and store it in a variable.
2. Ask for their age and store it.
3. Ask for their favorite subject in school and store it.
4. Use the len() function to get the length of their first name. Store this value.
5. Use int() to convert the user's age into an integer.
6. Perform the following calculation: (age ** 2) + len(first_name). Store the result in a
variable called calculation_result.

"""
name
age =  int()
fav_subject
name_len =

# %%
# Conditional Statements in Python
condition = True
if condition:
  print("condition is True")
  print("condition is True")
  print("condition is True")

else:
  print("Condition is False")
  print("Condition is False")
  print("Condition is False")
# Out:
# condition is True
# condition is True
# condition is True

# %%
age = int(input("Enter your age: "))
if age >=18:
  print("You are an adult")
  print("You can Vote")
else:
  print("You can't vote.")
  print("You are not eligible for voting.")

# %%
"""
Problem 1: Odd or Even?
Task:
Write a Python code  that determines if an integer variable named is even or odd.
(Hint: Use the modulo operator )
Input:

number = 13  # Try changing this value for testing!

Expected Output (for number = 13):The number 13 is Odd.

Expected Output (for number = 10):The number 10 is Even.



"""
# Out:
# '\nProblem 1: Odd or Even?\nTask: \nWrite a Python code  that determines if an integer variable named is even or odd. \n(Hint: Use the modulo operator )\nInput: \n\nnumber = 13  # Try changing this value for testing!\n\nExpected Output (for number = 13):The number 13 is Odd.\n\nExpected Output (for number = 10):The number 10 is Even.\n\n\n\n'

# %%
"""

Problem 2:
Task 2: Pass or Fail

Ask the user for their marks (0–100).

If marks are 50 or more, print "Pass"

Else print "Fail"S

"""

# %%
"""
Task:
Write a Python code  that determines if an integer variable named is even or odd.
(Hint: Use the modulo operator )

"""
num = int(input("Enter the number: "))
if num % 2 == 0:
  print("Even number.")
else:
  print("Odd number")
# Out:
# Enter the number: 15
# Odd number

# %%
"""
Task 5: Compare Two Numbers

Take two numbers from the user.

If the first number is greater than the second, print "First is bigger"

Else print "Second is bigger or equal"


"""

# %%
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))

if   num1 > num2:
  print("First is bigger")


else:
  print("Second is bigger or equal")
# Out:
# Enter the first number: 4
# Enter the second number: 2
# First is bigger

# %%
student_marks = int(input("Enter your marks: "))
if student_marks >=90:
  print("Grade A1")
elif student_marks >= 80:
  print("A grade")

elif student_marks >= 70:
  print("B grade")

elif student_marks >=50:
  print("C grade")
else:
  print("F Grade")
# Out:
# Enter your marks: 52
# C grade

# %%
# num
# find that if number is positive, negative or zero

# %%
marks = int(input("Enter your marks: "))
if marks >= 90 :
  print("Grade A+")

elif marks >=80:
  print("Grade A")

elif marks >= 70:
  print("Grade B")
elif marks >= 60:
  print("Grade C")

elif marks >=50:
  print("Grade D")
else:
  print("Grade F")
# Out:
# Enter your marks: 49
# Grade F

# %%
# take a number as input from user, find that if number is positive, negative or zero

# %%
"""
1. Ask the user to enter the weather (rainy or sunny).
If it is rainy, print “Take an umbrella”, otherwise print “Wear sunglasses”.

2. Ask the user to enter their age.
If the age is 5 or more, print “You can go to school”, else print “You are too young”.

3. Ask the user to enter a number.
Check whether the number is even or odd and print the result.

4. Ask the user to enter the color of a traffic light.
If the color is red, print “Stop”.
If it is yellow, print “Slow down”.
Otherwise, print “Go”.

5. Ask the user to enter the temperature.
If the temperature is greater than 30, print “Hot”.
If it is greater than 20, print “Warm”.
Otherwise, print “Cold”.

Ask the user to enter a password.
If the password is correct, print “Access granted”, else print “Wrong password”.

Ask the user to enter their marks.
Print Grade A for marks 90 or above, Grade B for 75 or above, Grade C for 50 or above, otherwise print “Fail”.

Ask the user to guess a number between 1 and 10.
If the guess is correct, print “Correct guess”, else print “Try again”.

Ask the user to enter the battery percentage.
If it is above 80, print “Battery Full”.
If it is above 30, print “Battery Medium”.
Otherwise, print “Battery Low”.

Ask the user to enter a day of the week.
If it is Sunday, print “Holiday”.
If it is Saturday, print “  Weekend”.
Otherwise, print “School day”.

Ask the user to enter a number.
Check whether the number is positive, negative, or zero and print the result.

Ask the user to enter their favorite game.
If the game is Cricket, print “You like outdoor games”, else print “You like indoor games”.



"""
