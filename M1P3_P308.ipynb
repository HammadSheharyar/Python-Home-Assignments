# %% [markdown]
# <a href="https://colab.research.google.com/github/HammadSheharyar/Python-Home-Assignments/blob/main/M1P3_P308.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1:

# %%
print("name")
print("Favourite animal")
# Out:
# name
# Favourite animal

# %% [markdown]
# Task 2:

# %%
print('Hello, World')
print('Hello')
# Out:
# Hello, World
# Hello

# %%
print('""hello')
print("'hello' world")
# Out:
# "hello"
# 'hello' world

# %%
print("hello world" , "programming", sep = " , ")
# Out:
# hello world , programming

# %%
print(5)
# Out:
# 5

# %%
# I said "Hello!" to my friend.
print('I said "Hello!" to my friend.')
print("I said 'Hello!' to my friend.")
#  It's time to play!
print("It's time to play! ")
# Out:
# I said "Hello!" to my friend.
# I said 'Hello!' to my friend.
# It's time to play!

# %%
print("This sentence is missing a quote")
# Out:
# This sentence is missing a quote

# %%
input("What is your name: ")
input("What is your age: ")
# Out:
# What is your name: ali
# What is your age: 10
# '10'

# %%
input("Enter the ist num: ")
input("Enter the 2nd num: ")
# Out:
# Enter the ist num: 1
# Enter the 2nd num: 2
# '2'

# %%
input("What is your name? ")
# Out:
# What is your name? Ali
# 'Ali'

# %%
input("Enter the ist number: ")
input("Enter the 2nd number: ")
# Out:
# Enter the ist number: 5
# Enter the 2nd number: 2
# '2'

# %% [markdown]
# Task 1:

# %%
input("What is your name? ")
# Out:
# What is your name? ali
# 'ali'

# %%
print("Hello\nPython\nProgramming")
# Out:
# Hello
# Python
# Programming

# %%
# \t
print("Hello\tPython\tProgramming")
# Out:
# Hello	Python	Programming

# %%
print("Python\nProgramming\n")
print("Hello, World\n")
print("Programming Language")
# Out:
# Python
# Programming
#
# Hello, World
#
# Programming Language

# %%
print("Python Programming")
print()
print("Hello, World")
print()
print("Programming Language")
# Out:
# Python Programming
#
# Hello, World
#
# Programming Language

# %%
# Asking Capital of France
input("What is the capital of France?")
# Out:
# What is the capital of France?paris
# 'paris'

# %%
# Data is piece of information
# numbers ___ age, year, text, paragrapgh, names, sentences,
# string >>>>> "Ali", "5"
print("Ali")
print(555)
# Out:
# Ali
# 555

# %%
# printing hello
print("I said 'hello' to my friend.")
# Out:
# I said 'hello' to my friend.

# %%
# Data types:
"""
Numbers: int ----> 1,2,3,4 whole numbers
         float ----> 1.2, 1.3, 1.4,33.5

String: text/sentence/name/paragraph ------> 'Ali', '5', "56", 'ali'

Boolean: False/True ----> 2 > 3 False, 2 < 3 True

"""

# %%
print("Ali")
'ali'
# Out:
# Ali
# 'ali'

# %%
45
# Out:
# 45

# %%
print(2 > 3)
print(3>2)
# Out:
# False
# True

# %%
is_going_to_school = False
# True == 1
# False == 0

# %%
a = 200 > 400
print(a)
type(a)
# Out:
# False
# bool

# %%
print(type(23))
print(type(23.56))
print(type("23"))
print(type("hello"))
print(type(False))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>

# %%
print(type("hi"))
# Out:
# <class 'str'>

# %%
int(2.265)
# Out:
# 2

# %%
float(232)
# Out:
# 232.0

# %%
# int to string
str(22)
# Out:
# '22'

# %%
# float into string
str(23.34)
# Out:
# '23.34'

# %%
# string into int
int("232323")
# Out:
# 232323

# %%
# string into float
float("23")
# Out:
# 23.0

# %%
# Arthmatic operators
# +, -, *, / , //, **, % modulo operator

print(2 + 3)
# Out:
# 5

# %%
# -
print(10 - 5 )
# Out:
# 5

# %%
# multiplication ( * )
print(3 * 2)
# Out:
# 6

# %%
# division /
print((8 / 3))
# Out:
# 2.6666666666666665

# %%
# floor division
print(8 // 3)
# Out:
# 2

# %%
# ** (power operator) Exponentiation
print(2 ** 4)
# Out:
# 16

# %%
print(3 ** 2)
# Out:
# 9

# %%
print(3 + 2)
# Out:
# 5

# %%
# modolu operator ( % )
print(8 % 4)
# Out:
# 0

# %%
print(8 % 3)
# Out:
# 2

# %%
# string operations
# string concatanation
# Addition
print("Python" + " " + "Programming" + " language")
# Out:
# Python Programming language

# %%
print(4 + 8)
print("4" + "8")
print("4 +  8")
# Out:
# 12
# 48
# 4 +  8

# %%
print("-"*50)
# multiplication by integer
print("ha"*5)

print("-"*50)
# Out:
# --------------------------------------------------
# hahahahaha
# --------------------------------------------------

# %%
print("Ali"*10)
# Out:
# AliAliAliAliAliAliAliAliAliAli

# %%
# len()
print(len("Python         Programming  343343"))
# Out:
# 34

# %%
len("python programming")
# Out:
# 18

# %%
len(" ")
# Out:
# 1

# %%
a = 10

# %%
a
# Out:
# 10

# %%
print(id(a))
# Out:
# 11654664

# %%
a +10
# Out:
# 20

# %%
name = "ali"

# %%
#
1 != 2
# Out:
# True

# %%
# coditional statements
num1 = int(input("num1: "))
num2 = int(input("num2: "))
if num1 > num2:
    print("hello")
    print("hello")

    print("hello")
    print("hello")
    print("hello")
else:
  print("bye")
# Out:
# num1: 100
# num2: 89
# hello
# hello
# hello
# hello
# hello

# %%
age = int(input("Enter your age: "))
if age >= 18:
  print("you are an adult")
  print("you can vote")

else:
  print("you can't vote")
# Out:
# Enter your age: 20
# you are an adult
# you can vote

# %%
age = 16
age >= 18
# Out:
# False

# %%
# take 2 numbers from the user and store them in 2 variables
# check if num1 is greater than num2  ------ first number is bigger
# second number is bigger
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
if num1 > num2:
  print("first number is bigger")
else:
  print("second number is bigger")
# Out:
# Enter the first number: 3
# Enter the second number: 5
# second number is bigger

# %%
"""
Task 3: Check Positive or Negative

Take an number as input.

If it is greater than 0, print "Positive"

Otherwise print "Negative"

"""

# %%
num = int(input("Enter a number: "))
if num > 0 :
  print("posivte number")
else:
  print("negative number")
# Out:
# Enter a number: 2
# posivte number

# %%
num1 =  int(input("Enter the first number"))
if num1 > 0:
  print("positive")

else:
  print("negative")
# Out:
# Enter the first number34
# positive

# %%
num1=int(input("Enter the first number"))
if num1>0:
  print("positive")
else:
  print("negative")
# Out:
# Enter the first number23
# positive

# %%
num1=int(input("Enter the first number"))
if num1>0:
  print("positive")
else:
  print("negative")
# Out:
# Enter the first number7
# positive
