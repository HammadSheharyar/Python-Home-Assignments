# %% [markdown]
# <a href="https://colab.research.google.com/github/HammadSheharyar/Python-Home-Assignments/blob/main/M1P3_P317.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1:

# %% [markdown]
# Displaying result

# %%
# print function
print('Hammad')
name = "Ali"
number_1 = 90
print(f"Python Programming Language, {name}")
print("python" , "programming", "language", sep = ",")
# Out:
# Hammad
# Python Programming Language, Ali
# python,programming,language

# %% [markdown]
# Task 2:

# %%
num_1 = input("Enter your name: ")
# Out:
# Enter your name: Ali

# %%
num_1
# Out:
# 'Ali'

# %%
print(2>3)
# Out:
# False

# %%
print(3>0)
# Out:
# True

# %%
type('hello')
# Out:
# str

# %%
int(2.0)
# Out:
# 2

# %%
float(2)
# Out:
# 2.0

# %%
num_2 = str(2)
type(num_2)
# Out:
# str

# %%
# Arthematic operations
# 2 +3
# print(2+3)
# print(2*3)
# print(2-3)
print((8/2))
print(6 / 3)
# floor division
print(6 // 3)
print(8 // 4)
# power
print(2 ** 5)
# Out:
# 4.0
# 2.0
# 2
# 2
# 32

# %%
print(3 ** 5 )
# Out:
# 243

# %%
my_name = "Muhammad Ali khan"
list1 = [1,2,3,4,5,6,7,12,1212,121212,22]
print(my_name)
len(my_name)
print(len(my_name))
print(len(list1))
# Out:
# Muhammad Ali khan
# 17
# 11

# %%
len("1343543563")
# Out:
# 10

# %%
str0 = ""
str1 = str()
print(str1)
print(len(str1))
print(len(str0))
# Out:
# 0
# 0

# %%
number = "12"
number_of_digits = len(number)
print("The number" , number, "has" , number_of_digits, "digits")
# Out:
# The number 12 has 2 digits

# %%
print("1 + 0")
print("1"+"0")
# Out:
# 1 + 0
# 10

# %%
print(8 % 3)
# Out:
# 2

# %%
str_2 = "ha"
print(str_2 * 5)
# Out:
# hahahahaha

# %%
name1 = "python "
name2 = "programming"
print(name1 * 3)
print(name1 + name2)
print("4" + "5" + "6" + "0")
print(4 + 5 + 0 )
# Out:
# python python python
# python programming
# 4560
# 9

# %%
num = str(7) + 7
print(num)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-55275442.py in <cell line: 0>()
# ----> 1 num = str(7) + 7
#       2 print(num)
#
# TypeError: can only concatenate str (not "int") to str

# %%
count = 10
# 1
count = count + 1
# count = 10 + 1 = 11
print(count)
# Out:
# 11

# %%
# increase count by 1
count = count + 1
print(count)
# decrease count by 1
count = count - 1
print(count)
# multiply count by 2
count = count * 2
print(count)
# Out:
# 12
# 11
# 22

# %%
# count = count + 1
print(count)
# count = count + 5
count += 5
print(count)
# count = count - 1
count -= 5
print(count)
# count = count * 2
count *= 5
print(count)
# Out:
# 22
# 27
# 22
# 110

# %%
# round()
# 99 ---> 100
# 1.232323
print(round(1.2323232, 2))
print(round(23.234, 1))

print(round(12345, -4))
# Out:
# 1.23
# 23.2
# 10000

# %%
# Area of triangle
# base
# height
# area
# base = (input("Enter the base: "))
base = 3.5
height = 7
area = 1 / 2 * base * height
print(area)
print("Rounded area is: ", round(area,1))
print("Area upto nearest integer is: ", round(area))
# Out:
# 12.25
# Rounded area is:  12.2
# Area upto nearest integer is:  12

# %%
# Step 1: Get the Name
# Create a variable named user_name.

# Use the input() function to ask the user to type in their first name. Store their response in the user_name variable.

# Step 2: Calculate the Length
# Create a new variable named name_length.

# Use the built-in len() function on your user_name variable. Assign the result to name_length.

# Step 3: Use the Modulo Operator
# Create a variable called remainder.
# name_length % 2
# Use the modulo operator (%) to find the remainder when name_length is divided by 2. The operation will look like this: name_length % 2.

# Assign the result of this operation to the remainder variable.

# Step 4: Display the Results
# Use the print() function to display a friendly message to the user.

# In your message, include the user's name, the length of their name, and the value of the remainder variable.

# Explain that if the remainder is 0, the name length is an even number. If the remainder is 1, it's an odd number.

# %%
# Comparision operators
# >, < , == , >= , <=, !=

print(4 > 3)
print(4 > 5)
print(45 > 54)
# Out:
# True
# False
# False

# %%
# <
print(2<3)
print(1<0)
print(0 < 1)
a = 10
b = 20
c = a < b
print(c)
# Out:
# True
# False
# True
# True

# %%
# >=, > , =
print(2 < 2)
print(2 <= 2)
print(3 > 3)
print(2 >= 3 )
# Out:
# False
# True
# False
# False

# %%
# ==
print(1 == 2)
# =
num = 1
# Out:
# False

# %%
print(1 == 1)
# Out:
# True

# %%
# !=
print( 1 != 1)
# Out:
# False

# %%
# Logical operators
# And , Or, not
print(2 > 3 and 2 < 3)
print(True and False)
print(0 and 1)
print(0 and 0)
print(1 and 1)
print(True and True)
print(1 and 2)
print(3 and  2)
# Out:
# False
# False
# 0
# 0
# 1
# True
# 2
# 2

# %%
# Or
print(1 < 2 or 2 < 1)
# Out:
# True

# %%
print(not True)
print(not False)
print(not(True))
# Out:
# False
# True
# False

# %%
print(not(1 < 2 or 2 < 1))
# Out:
# False

# %%
not 1
# Out:
# False

# %%
x = 3+5j
y = 5j
z = -5j

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
# Activity:
secret_number = 15
print("Guess the secret number!" )
user_guess = input("Enter your guess: ")
user_guess = int(user_guess)
is_correct = (user_guess == secret_number)
is_to_high = user_guess > secret_number
is_to_low = user_guess < secret_number
is_not_correct = user_guess != secret_number
is_close = (user_guess > 10) and (user_guess < 20)
print("Is your guess correct?", is_correct)
print("Is your guess too high?", is_to_high )
print("Is your guess too low?", is_to_low )
print( "Is your guess incorrect?", is_not_correct )
print( "Is your guess close (between 10 and 20)?", is_close )
# Out:
# Guess the secret number!
# Enter your guess: 45
# Is your guess correct? False
# Is your guess too high? True
# Is your guess too low? False
# Is your guess incorrect? True
# Is your guess close (between 10 and 20)? False

# %%
# Conditional Statments
condition = True
if condition:
  print("Condition is True.")


print("Ends")
# Out:
# Condition is True.
# Ends

# %%
condition = False
if condition:
  print("Condition is True.")


print("Ends")
# Out:
# Ends

# %%
a = 10
if a < 20:
  print("Condition is True")
  b = 10
  print(b)
# Out:
# Condition is True
# 10

# %%
b < 10 and c < 20
# Out:
# True

# %%
b < 10 or c < 15
# Out:
# True

# %%
b = 5
c = 15
if b < 10 or c < 15:
  print("Both Conditions are True.")
  print("Both are true")

if b < 10 and c < 20:
  print("Both Conditions are True.")
  print("Both are true")

print("End of if block")
# Out:
# Both Conditions are True.
# Both are true
# Both Conditions are True.
# Both are true
# End of if block

# %%
# if-else condition
if condition:
  # body of if block
else:
  # body of else block

# %%
b = 5
if b == 4:
  print("b is 5")
else:
  print("b is not 5")
  print("else condition")



print("this is indpendent statement, and does not depends on if-else")
# Out:
# b is not 5
# else condition
# this is indpendent statement, and does not depends on if-else

# %%
# even and odd number
number = int(input("Enter the number: "))
if number % 2 == 0:
  print("Even number")
else:
  print("Odd number.")
# Out:
# Enter the number: 9
# Odd number.

# %%
# take number from user
# check for positive and negative
number = int(input("Enter the number: "))
if number >= 0:
  print("number is positive")

else:
  print("number is negative")
# Out:
# Enter the number: -1
# number is negative

# %%
print("One\nTwo\nThree")
# Out:
# One
# Two
# Three

# %%
# elif -----> else if
value =int(input("Enter the number: "))
if value < 10:
  print("value was less than 10")
elif value > 10:
  print("Value was greater than 10")
else:
  print("value is niether less than nor greater than 10")
# Out:
# Enter the number: -676
# value was less than 10

# %%
# x
# x == 0
# x > 0
# x < 0
# i have never seen this one before

# %%
""" What is a variable in Python? Give two examples.
Ans:


"""

# %%
# vote
age = int(input("Enter your age: "))
if age >= 18:
  print("You can vote.")
else:
  print("you can't vote.")
# Out:
# Enter your age: 12
# you can't vote.

# %%
# ask password user
# password is equal to "python"
# Welcome message
# Access is Denied

# %%
# Grade Evaluator
# read marks
# >= 90 , grade A
# >=80 , grade B
# >= 70 , grade C
# >= 60, grade D
# grade is F

# %%
# read password
# find length
# if lenght < 6, weak
# if length <= 10, medium
# stron password

# %%
# Out:
# Enter your marks: 444
# invalid
# Your grade: f

# %%
"""
Task
Given an integer, , perform the following conditional actions:

If  is odd, print Weird
If  is even and in the inclusive range of  to (10-30), print Not Weird
If  is even and in the inclusive range of  to (30 - 40), print Weird
If  is even and greater than 50, print Not Weird
Input Format

A single line containing a positive integer, .


Output Format

Print Weird if the number is weird. Otherwise, print Not Weird.

Sample Input:

3


Weird

"""

# %%
num = (int(input("Enter your number: ")))
if num % 2 != 0 or 30 <= num > 40:
  print("weird")
elif num % 2 == 0 and (10 <= num > 30 or num > 50):
  print("not weird")
else:
  print("unknown error")

# %%
# nested if-else
# if condition:

#   if condition:

#   else:



# else:

# %%
# Out:
# Enter the username: admin
# Enter the password: 1234
# Login Successfully.

# %%
# num
# >=0
#   even (postive and even)
#

# %%
username = input("Enter the username: ")
password = input("Enter the password: ")
if username == "admin":
  if password == "1234":
    print("Login Successfully.")
  else:
    print("incorrect password")
else:
  print("unkown username")

# %%
"""

Task no 2:

An extra day is added to the calendar almost every four years as February 29, and the day is called a leap day. It corrects the calendar for the fact that our planet takes approximately 365.25 days to orbit the sun. A leap year contains a leap day.

In the Gregorian calendar, three conditions are used to identify leap years:

The year can be evenly divided by 4, is a leap year, unless:
The year can be evenly divided by 100, it is NOT a leap year, unless:
The year is also evenly divisible by 400. Then it is a leap year.
This means that in the Gregorian calendar, the years 2000 and 2400 are leap years, while 1800, 1900, 2100, 2200, 2300 and 2500 are NOT leap years. Source

Task

Given a year, determine whether it is a leap year. If it is a leap year, return the Boolean True, otherwise return False.

Note that the code stub provided reads from STDIN and passes arguments to the is_leap function. It is only necessary to complete the is_leap function.

Input Format

Read , the year to test.

Constraints


Output Format

The function must return a Boolean value (True/False). Output is handled by the provided code stub.

Sample Input 0

1990
Sample Output 0

False



"""

# %%
"""
Task
Given an integer, n , perform the following conditional actions:
If n  is odd, print Weird
If n is even and in the inclusive range of 2 to 5, print Not Weird
If n is even and in the inclusive range of 6 to 20, print Weird
If n is even and greater than 20, print Not Weird
"""

# %%
if 5>10:
  print("A");
elif 5==10:
  print("B");
else:
  print("C")
# Out:
# C

# %%
num = 19
print(num)
# Out:
# 19

# %%
num + 10
# Out:
# 29

# %%
num -9
# Out:
# 10

# %%
"""
"Identify the Type of Triangle using Python"
📝 Problem Statement:
Write a Python program that accepts the lengths of three sides of a triangle and determines:
Whether the given sides can form a valid triangle or not.


If valid, determine whether the triangle is:


Equilateral (all sides equal)


Isosceles (two sides equal)


Scalene (all sides different)


📘 Conditions to Remember:
A triangle is valid only if the sum of any two sides is greater than the third side.
 That is:
(a + b) > c
(a + c) > b
(b + c) > a

💡 Hints:
Take inputs for the three sides.


First, check if the triangle is valid.


If valid, use conditional statements to identify its type.


Display appropriate messages for each case.


📤 Expected Output Example:
Enter side a: 5
Enter side b: 5
Enter side c: 8

These sides can form a triangle.
Type: Isosceles Triangle


"""

# %%
"""
Write a Python program that displays a menu of math operations.
 The program should perform basic calculations and number-based tasks like addition, subtraction, multiplication, squares, cubes, etc.
Your program should:
Display the following menu once:

1. Basic Arithmetic (Add, Subtract, Multiply, Divide)
2. Square and Cube of a Number
3. Check if a Number is Even or Odd
4. Find the Greater of Two Numbers
5. Find the Area of Basic Shapes (Circle, Rectangle, Triangle)
6. Exit


Ask the user for their choice (1–6).


Take the required inputs and perform the calculation.


Display clear, labeled results.


Do not use loops (run once and exit).

"""

# %%
"""
Write a Python program that displays a menu of math operations.
 The program should perform basic calculations and number-based tasks like
 addition, subtraction, multiplication, squares, cubes, etc.
Your program should:
Display the following menu once:

1. Basic Arithmetic (Add, Subtract, Multiply, Divide)
2. Square and Cube of a Number
3. Check if a Number is Even or Odd
4. Find the Greater of Two Numbers
5. Find the Area of Basic Shapes (Circle, Rectangle, Triangle)
6. Exit


Ask the user for their choice (1–6).

Take the required inputs and perform the calculation.

Display clear, labeled results.

📘 Math Concepts Used
Concept
Formula / Description
Addition
a + b
Subtraction
a - b
Multiplication
a × b
Division
a / b
Square
n²
Cube
n³
Even/Odd
If n % 2 == 0 → Even, else Odd
Greater Number
Compare a > b
Area of Circle
π × r²
Area of Rectangle
l × w
Area of Triangle
½ × b × h


"""

# %%
# ============================================================
# Project: Math Fun Calculator
# Author: Your Name
# Description: A fun math calculator for basic learning
# ============================================================


print("===============================================")
print("🎉 KIDS' MATH FUN CALCULATOR 🎨")
print("===============================================")
print("1. Basic Arithmetic (Add, Subtract, Multiply, Divide)")
print("2. Square and Cube of a Number")
print("3. Check if a Number is Even or Odd")
print("4. Find the Greater of Two Numbers")
print("5. Find the Area of Basic Shapes")
print("6. Exit")
print("===============================================")

# %%
"""
Write a Python program that acts like a Math Quiz Game.
The program should display a menu of different math challenges,
ask the user a question, get their answer, and then tell them if their answer is correct or not.

The menu should be:
1. Addition Challenge
2. Subtraction Challenge
3. Multiplication Challenge
4. Division Challenge
5. Number Comparison
6. Exit

Your program should:
Display the menu once.


Ask the user to pick a challenge (1–6).
Take the required inputs (numbers).
Ask the user for their answer to a math problem.
Check if it’s correct or wrong, then display a message.
"""

# %%
# ============================================================
# Project: Math Fun Calculator
# Author: Your Name
# Description: A fun math calculator for basic learning
# ============================================================


print("===============================================")
print("🎉 MATH FUN CALCULATOR 🎨")
print("===============================================")
print("1. Addition Challenge")
print("2. Square and Cube of a Number")
print("3. Check if a Number is Even or Odd")
print("4. Find the Greater of Two Numbers")
print("5. Find the Area of Basic Shapes")
print("6. Exit")
print("===============================================")

# %%
# Conditional Expression =====> Short/Simplified version of if-else statement
x = 10
y = 20
if x > y:
  print(x)
else:
  print(y)
# Out:
# 20

# %%
greater = x if x>y else y
print(greater)
# Out:
# 20

# %%
"""
Create a Python program that acts as a Math Puzzle Builder.
The program should:
Present 3–4 different math puzzles (addition, subtraction, multiplication, division, or comparing numbers).


Ask the user to answer each puzzle.


Keep track of correct answers and calculate a score at the end.


Display a final message based on the score.


"""
# Your output should be like this
"""
🧩 Example Output
Puzzle 1: Addition
Enter first number: 5
Enter second number: 3
What is 5.0 + 3.0? 8
✅ Correct!

Puzzle 2: Subtraction
Enter first number: 9
Enter second number: 4
What is 9.0 - 4.0? 6
❌ Wrong!

Puzzle 3: Multiplication
Enter first number: 2
Enter second number: 6
What is 2.0 × 6.0? 12
✅ Correct!

Puzzle 4: Compare Numbers
Enter first number: 7
Enter second number: 7
Which number is greater? (a/b/equal): equal
✅ Correct!

🏆 Your Score: 3 / 4
👍 Good Job! Keep Practicing!

"""

# %%
# loops
# while loop, for loop

# Counting
while condition:
  print()

# %%
count = 1
while count <=5:
  print(count)
  count +=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
count = 5
while count >= 0:
  print(count)
  count -=1
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
command = ""
while command != "stop":
  command = input("Type a command: ").lower()
  print(command)

print("Program ended!")
# Out:
# Type a command: 123
# 123
# Type a command: 233
# 233
# Type a command: STOP
# stop
# Program ended!

# %%
password = ""
while password != "python123":
  password = input("Enter the password: ").lower()
  print(password)

print("Access granted!!")
# Out:
# Enter the password: 123
# 123
# Enter the password: 4323
# 4323
# Enter the password: 2232
# 2232
# Enter the password: python123
# python123
# Access granted!!

# %%
secret = 7
guess = 0
while guess != secret :
  guess = int(input("Enter a number (1-10)! "))
print("correct")
# Out:
# correct

# %%
# infinite loop
while True:
  print("hello")

# %%
while True:
  answer  = input("Type q to quite: ").lower()
  if answer == "q":
    break
# Out:
# Type q to quite: 5
# Type q to quite: 8
# Type q to quite: q

# %%
# add numbers untill the user stops

# %%
# repeat untill counter reaches the target
# progress = 0
# goal = 100
